# %%
import matplotlib.pyplot as plt

# Data
epochs = list(range(1, 11))

relu_accuracy = [43.82, 49.58, 51.64, 51.64, 54.59, 54.20, 53.82, 54.99, 55.07, 55.47]
leaky_relu_accuracy = [44.10, 50.10, 51.09, 53.62, 54.46, 54.53, 54.67, 54.91, 55.35, 55.62]
sigmoid_accuracy = [45.78, 49.72, 51.88, 52.69, 53.09, 51.15, 52.32, 53.50, 53.25, 53.17]
tanh_accuracy = [41.17, 36.02, 31.76, 35.39, 38.14, 41.62, 38.91, 35.05, 43.88, 42.34]
gelu_accuracy = [44.55, 49.50, 52.24, 53.60, 54.26, 54.67, 54.89, 54.67, 54.44, 54.93]
elu_accuracy = [47.52, 50.48, 51.84, 51.80, 51.82, 53.07, 53.31, 54.06, 54.53, 54.06]
selu_accuracy = [48.67, 51.70, 52.61, 54.16, 53.66, 52.95, 54.12, 54.55, 54.79, 54.04]

# Plotting Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs, relu_accuracy, label='ReLU', marker='o', color='blue')
plt.plot(epochs, leaky_relu_accuracy, label='LeakyReLU', marker='o', color='green')
plt.plot(epochs, sigmoid_accuracy, label='Sigmoid', marker='o', color='red')
plt.plot(epochs, tanh_accuracy, label='Tanh', marker='o', color='purple')
plt.plot(epochs, gelu_accuracy, label='GELU', marker='o', color='orange')
plt.plot(epochs, elu_accuracy, label='ELU', marker='o', color='cyan')
plt.plot(epochs, selu_accuracy, label='SELU', marker='o', color='magenta')

# Adding labels and title
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
# plt.title('Accuracy of Different Activation Functions over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Data
relu_loss = [3.003362649942782, 2.107947537812463, 1.8971661885264683, 1.7748505429780916, 1.697144288953775, 1.6221988953379514, 1.5813408573547212, 1.522713335842976, 1.4970856337657463, 1.460578350627383]
leaky_relu_loss = [2.984332027120559, 2.0752104894870973, 1.8316994041971641, 1.688598360558941, 1.5807579373683867, 1.508398028049532, 1.4577235056936937, 1.398216024987375, 1.3252378053476315, 1.2980224394719593]
sigmoid_loss = [2.752225825149234, 1.9627413496011161, 1.7327472404599584, 1.6026063815359235, 1.5137876959759804, 1.4367134041676033, 1.3712126957229263, 1.3298223209538476, 1.2827396533355462, 1.2532014504360287]
tanh_loss = [2.82760445783634, 2.252169955602967, 2.3233098478915273, 2.431577464534898, 2.3449652303878232, 2.3063742638893254, 2.2880060771589625, 2.215580298688152, 2.230927537675738, 2.1815729218662376]
gelu_loss = [2.948743046518206, 2.08930755229673, 1.8409767489228706, 1.702685177648815, 1.615744989634347, 1.5440935794276374, 1.4787115701039633, 1.4228169222476066, 1.3889542832232937, 1.3390540589436446]
elu_loss = [2.7823452934416215, 1.9659952034021762, 1.7234606070565706, 1.5906360514643956, 1.4935203028197335, 1.4062849050622568, 1.336015062143307, 1.2710671628819834, 1.2066855679880275, 1.1614942001116157]
selu_loss = [2.7689291376800034, 1.9561645793285307, 1.7245178157504242, 1.6038831604746702, 1.4958719824643025, 1.4363104361669459, 1.3597361443381104, 1.314529145621624, 1.2564156902505226, 1.189550335430863]

# Plotting Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs, relu_loss, label='ReLU', marker='o', color='blue')
plt.plot(epochs, leaky_relu_loss, label='LeakyReLU', marker='o', color='green')
plt.plot(epochs, sigmoid_loss, label='Sigmoid', marker='o', color='red')
plt.plot(epochs, tanh_loss, label='Tanh', marker='o', color='purple')
plt.plot(epochs, gelu_loss, label='GELU', marker='o', color='orange')
plt.plot(epochs, elu_loss, label='ELU', marker='o', color='cyan')
plt.plot(epochs, selu_loss, label='SELU', marker='o', color='magenta')

# Adding labels and title
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.title('Loss of Different Activation Functions over Epochs')
plt.legend()
plt.grid(True)
plt.show()
